# %% [markdown]
# Caminata aleatoria 1D
# Neri Frias Luis Enrique

# %% [markdown]
# En este programa se simula una caminata aleatoria unidimensional.
# En cada paso se genera una variable aleatoria uniforme
# $𝑉∼𝑈(0,1)$ Si $𝑉<𝑝$ la posición aumenta en una unidad; en caso contrario disminuye en una unidad.

# %%
def camalet():
    V=random()
    if V<p:
        suma=suma+1
    else:
        suma=suma-1
    return suma

# %% [markdown]
# Posteriormente, en el programa principal, añadimos la variable suma la cual se distribuye binomialmente con los valores de las sumas de la variable aletaria de bernoulli.

# %%
import matplotlib.pyplot as plt
from random import random

N=100
ns=[]
suma=0
p = 0.6

sumas=[]
for i in range(N):
    ns.append(i)
    suma=suma+camalet()
    sumas.append(suma)

#print(sumas)

# gráfica
plt.plot(ns, sumas)
plt.axhline(0, color='black', linestyle='--', alpha=0.5)
plt.xlabel("Número de simulaciones (n)")
plt.ylabel("valor de suma")
plt.title("Caminata aleatoria")
plt.show()

# %%
Conclusiones: 
Fue importante generar listas para visualizar como iban generandose las variables de suma. 
El valor de p influye hacia donde se dirige la tendencia si arriba o hacia abajo.
